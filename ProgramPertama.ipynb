# %%
#ini adalah contoh program pytjon pertama
"""
next meeting
kita akan pelajari mengenai
tipe data, operator, dan control (if-else,for,while)
"""

x=80
y=5
a="Pemrograman"
b=" Berorientasi"
c=" Objek"

print ("hasil penambahan: ", x+y)
print ("hasil pengurangan: ", x-y)
print ("hasil perkalian: ", x*y)
print ("hasil pembagian: ", x/y,"\n")
print (a+b+c)
print ("stay calm keep coding")
# Out:
# hasil penambahan:  85
# hasil pengurangan:  75
# hasil perkalian:  400
# hasil pembagian:  16.0
#
# Pemrograman Berorientasi Objek
# stay calm keep coding
